# %% [markdown]
# # OpenCV Basics

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# ## Reading and showing images

# %%
img_location: str = '../images/img_2048x2494x15.jpg'

# %%
# We load the image in memory in a given variable
img = cv.imread(img_location)

# %%
# This does not work if jupyter client and an server are on different machines
# cv.imshow('Original Lungs Xray', img)
# cv.waitKey(0)  # waits an infinite amount of time when 0 is passed
# Using matplotlib instead:
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Reading and displaying videos

# %%
# if integer is passed it then matches the cameras that you have currently working
# capture = cv.VideoCapture('path_to_video_file')

# while True:
#     isTrue, frame = capture.read()
#     cv.imshow('Video', frame)
#     if cv.waitKey(20) & 0XFF==ord('d'):  # waits for 20 ms for the letter d to be pressed
#         break
        
# capture.release()
# cv.destroyAllWindows()

# %% [markdown]
# ## Resizing and rescaling frames

# %%
# This method can work with videos and images
def rescaleFrame(frame, scale=0.75):
    width = int(frame.shape[1] * scale)
    height = int(frame.shape[0] * scale)
    dimensions = (width, height)
    
    return cv.resize(frame, dimensions, interpolation=cv.INTER_AREA)

# This method works only with videos
def changeRes(width, height):
    capture.set(3, widht)
    capture.set(4, heihg)

# %%
resized_img = rescaleFrame(img, 0.2)
plt.imshow(resized_img)
plt.show()

# %% [markdown]
# ## Drawing shapes and write text on a image

# %% [markdown]
# # Bibliography
#
# - Github repo with original code: [link to opencv-course](https://github.com/jasmcaus/opencv-course)
